# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
def cost_function(X,Y,W):
    m = dataset.shape[0]
    prediction = np.dot(X,W)
    error = prediction - Y
    cost = 1/(2*m) * np.dot(error.T,error)
    return (cost,error)

# %%
def gradient_descent(X,Y,W,learning_rate,no_of_iterations):
    cost_history = []
    weights_history = [W]
    for i in range(no_of_iterations):
        m = len(Y)
        prediction = np.dot(X,W)
        error = prediction - Y
        cost = (1/(2*m) )* np.dot(error.T,error)
        cost_history.append(cost)
#         print(learning_rate*(1/m)*np.dot(error.T,X))
        W = W - (learning_rate*(1/m)*np.dot(X.T,error))
        weights_history.append(W)
    return (cost_history,weights_history)

# %%
df = pd.read_csv("./linear.csv")
df.head(5)
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
X = df['SAT']
# X = (X - X.mean()) / X.std()
X = np.c_[np.ones(X.shape[0]), X]
X_train = X[160:,:]
# X = X[0:140,:]
Y = df['GPA']
Y = Y.to_numpy()
Y_train = Y[160:]
# Y = Y[0:140]
W = np.random.rand(2)
# print(X)
# print(Y)
cost_history,weights_history = gradient_descent(X,Y,W,9.99e-08,20)
W = weights_history[-1]
print(cost_history[-1])
# Out:
# 0.02349541468769898

# %%
plt.title('Cost Function J')
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.plot(cost_history)
plt.show()

# %%
fig = plt.figure()
plt.title("No. of hours vs Rank")
plt.xlabel("No. of hours")
plt.ylabel("Rank obtained")
plt.plot(X[:,1],Y,"o")
x = np.linspace(1600, 2100, 200)
plt.plot(x,W[0] + W[1]*x,linestyle="dashed")
plt.show()

# %%
predicted_gpa = np.dot(X_train,W)
# print(X_train)
# print(Y_train)
fig = plt.figure()
plt.title("No. of hours vs Rank")
plt.xlabel("No. of hours")
plt.ylabel("Rank obtained")
plt.plot(X_train[:,1],Y_train,"o")
plt.plot(X_train[:,1],predicted_gpa,"r+")
plt.show()

# %%
W = np.random.rand(5)
X = df['SAT']
X =  (X - X.mean())/(X.max() -X.min())   #normalization
X = np.c_[np.ones(X.shape[0]),X,X**2,X**3,X**4]
X_train = X[80:90,:]
# X = X[0:140,:]
Y = df['GPA']
Y = Y.to_numpy()
Y_train = Y[80:90]
# Y = Y[0:140]
# print(X)
# print(Y)
# print(W)
cost_history,weights_history = gradient_descent(X,Y,W,0.5e-02,800)
W = weights_history[-1]
# print(W)
print(cost_history[-1])
# Out:
# 0.026248683620004133

# %%
plt.title('Cost Function J')
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.plot(cost_history)
plt.show()

# %%
fig = plt.figure()
plt.title("No. of hours vs Rank")
plt.xlabel("No. of hours")
plt.ylabel("Rank obtained")
plt.plot(X[:,1],Y,"o")
x = np.linspace(-0.6, 0.6, 20)
# coeff = [W[0],W[1],W[2],W[3]]
plt.plot(x,W[0] + W[1]*x + W[2]*(x**2) + W[3]*(x**3) + W[4]*(x**4),linestyle="dashed")
plt.show()

# %%
predicted_gpa = np.dot(X_train,W)
# print(X_train)
# print(Y_train)
fig = plt.figure()
plt.title("No. of hours vs Rank")
plt.xlabel("No. of hours")
plt.ylabel("Rank obtained")
plt.plot(X_train[:,1],Y_train,"o")
plt.plot(X_train[:,1],predicted_gpa,"r+")
plt.show()

# %%
W = np.random.rand(3)
a = 1600
b = 2
X = df['SAT']
# X =  (X - X.mean())/X.std()
# print(X)
X2 = np.sin((1/b)*(X - a*np.ones(X.shape[0])))
# print(X2)
X = np.c_[np.ones(X.shape[0]),X,X2]
X_train = X[70:80,:]
X = X[0:140,:]
Y = df['GPA']
Y = Y.to_numpy()
Y_train = Y[70:80]
Y = Y[0:140]
# print(X)
# print(Y)
# print(W)
cost_history,weights_history = gradient_descent(X,Y,W,1.0e-08,500)  ##learning_rate = 1.0e-08
W = weights_history[-1]
print(W)
print(cost_history[-1])
# Out:
# [0.68700873 0.0014369  0.42483   ]
# 0.06878255416703187

# %%
plt.title('Cost Function J')
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
plt.plot(cost_history)
plt.show()

# %%
fig = plt.figure()
plt.title("No. of hours vs Rank")
plt.xlabel("No. of hours")
plt.ylabel("Rank obtained")
plt.plot(X[:,1],Y,"o")
x = np.linspace(1620, 2050, 500)
# coeff = [W[0],W[1],W[2],W[3]]
plt.plot(x,W[0] + W[1]*x + W[2]*np.sin((x-a)/b),linestyle="dashed")
plt.show()

# %%
predicted_gpa = np.dot(X_train,W)
# print(X_train)
# print(Y_train)
fig = plt.figure()
plt.title("No. of hours vs Rank")
plt.xlabel("No. of hours")
plt.ylabel("Rank obtained")
plt.plot(X_train[:,1],Y_train,"o")
plt.plot(X_train[:,1],predicted_gpa,"r+")
plt.show()
